# %%
# from google.colab import drive
# drive.mount('/content/drive')

# %%
res_folder = "./res"
dataset_folder = "./data/train"
check_point_dir = "./res"

# %%
import os
import torch
import torch.nn as nn
import matplotlib.pyplot as plt

# %%
device = "cuda" if torch.cuda.is_available() else "cpu"

# %%
def inverse_transform(tensors):
    return ((tensors.clamp(-1, 1) + 1.0) / 2.0) * 255.0

# %%
class DiffusionHelper:
    def __init__(self,
                 noise_steps = 1000,
                 beta_start = 1e-4,
                 beta_end = 0.02,
                 img_size = 64,
                 device = "cuda"
                 ):
        self.noise_steps = noise_steps
        self.beta_start = beta_start
        self.beta_end = beta_end
        self.img_size = img_size
        self.device = device

        self.beta = self.prepare_noise_schedule().to(device)
        self.alpha = 1 - self.beta

        self.alpha_hat = torch.cumprod(self.alpha, dim=0)

    def prepare_noise_schedule(self):
        return torch.linspace(self.beta_start, self.beta_end, self.noise_steps)

    def add_noise(self, x, t):
        sqrt_alpha_hat = torch.sqrt(self.alpha_hat[t])[:, None, None, None]
        sqrt_one_minus_alpha_hat = torch.sqrt(1-self.alpha_hat[t])[:, None, None, None]
        eps = torch.randn_like(x)
        return sqrt_alpha_hat*x + sqrt_one_minus_alpha_hat*eps, eps

    def sample_timesteps(self, n):
        return torch.randint(1, self.noise_steps, size=(n,))

    def sample(self, model, n):
        model.eval()
        with torch.no_grad():
            x = torch.randn((n, 3, self.img_size, self.img_size)).to(self.device)
            for i in reversed(range(1, self.noise_steps)):
                t = (torch.ones(n) * i).long().to(self.device)
                predicted_noise = model(x, t)
                alpha = self.alpha[t][:, None, None, None]
                alpha_hat = self.alpha_hat[t][:, None, None, None]
                beta = self.beta[t][:, None, None, None]
                if i > 1:
                    noise = torch.randn_like(x)
                else:
                    noise = torch.zeros_like(x)
                x = 1 / torch.sqrt(alpha) * (x - ((1 - alpha) / (torch.sqrt(1 - alpha_hat))) * predicted_noise) + torch.sqrt(beta) * noise
        model.train()
        x = (x.clamp(-1, 1) + 1) / 2
        x = (x * 255).type(torch.uint8)
        return x

# %%
import torchvision.datasets as datasets
from torch.utils.data import Dataset, DataLoader
import torchvision.transforms
from torchvision.datasets import ImageFolder

transforms = torchvision.transforms.Compose(
        [
            torchvision.transforms.Resize((32, 32)),
            torchvision.transforms.ToTensor(),
            torchvision.transforms.Lambda(lambda t: (t * 2) - 1)
        ]
    )


# dataset = datasets.CIFAR10(root="data", train=True, download=True, transform=transforms)
dataset = ImageFolder(dataset_folder, transform=transforms)

# %%
dataloader = DataLoader(dataset, batch_size=16,
                            shuffle=True)
vis_loader = DataLoader(dataset, batch_size=6,
                            shuffle=True)

# %%
from torchvision.utils import make_grid

plt.figure(figsize=(10, 4), facecolor='white')

for b_image, _ in dataloader:
    b_image = inverse_transform(b_image)
    grid_img = make_grid(b_image / 255.0, nrow=16, padding=True, pad_value=1)
    plt.imshow(grid_img.permute(1, 2, 0))
    plt.axis("off")
    break

# %%
diffusion_helper = DiffusionHelper(img_size=32, device=device)

# %%
noisy_images = []
specific_timesteps = [0, 10, 50, 100, 150, 200, 250, 300, 400, 600, 800, 999]

images, labels = next(iter(vis_loader))

for timestep in specific_timesteps:
    timestep = torch.as_tensor([[[timestep]]], dtype=torch.long)

    xts, _ = diffusion_helper.add_noise(images.to(device), timestep)
    xts = inverse_transform(xts[:, None, None, None])

    noisy_images.append(xts)

# %%
_, ax = plt.subplots(6, len(noisy_images), figsize=(12, 6))

for j, (timestep, noisy_sample) in enumerate(zip(specific_timesteps, noisy_images)):
    noisy_sample = torch.squeeze(noisy_sample, dim=(0, 1, 2, 3, 4))
    for i in range(len(noisy_sample)):
        ax[i][j].imshow((noisy_sample[i].permute(1, 2, 0)/255.0).cpu())
        ax[i][j].set_title(f"t={timestep}", fontsize=8)
        ax[i][j].axis("off")
        ax[i][j].grid(False)

plt.axis("off")
plt.show()

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F


class SelfAttention(nn.Module):
    def __init__(self, channels, size):
        super(SelfAttention, self).__init__()
        self.channels = channels
        self.size = size
        self.mha = nn.MultiheadAttention(channels, 4, batch_first=True)
        self.ln = nn.LayerNorm([channels])
        self.ff_self = nn.Sequential(
            nn.LayerNorm([channels]),
            nn.Linear(channels, channels),
            nn.GELU(),
            nn.Linear(channels, channels),
        )

    def forward(self, x):
        x = x.view(-1, self.channels, self.size * self.size).swapaxes(1, 2)
        x_ln = self.ln(x)
        attention_value, _ = self.mha(x_ln, x_ln, x_ln)
        attention_value = attention_value + x
        attention_value = self.ff_self(attention_value) + attention_value
        return attention_value.swapaxes(2, 1).view(-1, self.channels, self.size, self.size)


class DoubleConv(nn.Module):
    def __init__(self, in_channels, out_channels, mid_channels=None, residual=False):
        super().__init__()
        self.residual = residual
        if not mid_channels:
            mid_channels = out_channels
        self.double_conv = nn.Sequential(
            nn.Conv2d(in_channels, mid_channels, kernel_size=3, padding=1, bias=False),
            nn.GroupNorm(1, mid_channels),
            nn.GELU(),
            nn.Conv2d(mid_channels, out_channels, kernel_size=3, padding=1, bias=False),
            nn.GroupNorm(1, out_channels),
        )

    def forward(self, x):
        if self.residual:
            return F.gelu(x + self.double_conv(x))
        else:
            return self.double_conv(x)


class Down(nn.Module):
    def __init__(self, in_channels, out_channels, emb_dim=256):
        super().__init__()
        self.maxpool_conv = nn.Sequential(
            nn.MaxPool2d(2),
            DoubleConv(in_channels, in_channels, residual=True),
            DoubleConv(in_channels, out_channels),
        )

        self.emb_layer = nn.Sequential(
            nn.SiLU(),
            nn.Linear(
                emb_dim,
                out_channels
            ),
        )

    def forward(self, x, t):
        x = self.maxpool_conv(x)
        emb = self.emb_layer(t)[:, :, None, None].repeat(1, 1, x.shape[-2], x.shape[-1])
        return x + emb


class Up(nn.Module):
    def __init__(self, in_channels, out_channels, emb_dim=256):
        super().__init__()

        self.up = nn.Upsample(scale_factor=2, mode="bilinear", align_corners=True)
        self.conv = nn.Sequential(
            DoubleConv(in_channels, in_channels, residual=True),
            DoubleConv(in_channels, out_channels, in_channels // 2),
        )

        self.emb_layer = nn.Sequential(
            nn.SiLU(),
            nn.Linear(
                emb_dim,
                out_channels
            ),
        )

    def forward(self, x, skip_x, t):
        x = self.up(x)
        x = torch.cat([skip_x, x], dim=1)
        x = self.conv(x)
        emb = self.emb_layer(t)[:, :, None, None].repeat(1, 1, x.shape[-2], x.shape[-1])
        return x + emb


class UNet(nn.Module):
    def __init__(self, c_in=3, c_out=3, time_dim=256, device="cuda"):
        super().__init__()
        self.device = device
        self.time_dim = time_dim
        self.inc = DoubleConv(c_in, 64)
        self.down1 = Down(64, 128)
        self.sa1 = SelfAttention(128, 16)
        self.down2 = Down(128, 128)
        self.sa2 = SelfAttention(128, 8)

        self.bot1 = DoubleConv(128, 256)
        self.bot2 = DoubleConv(256, 256)
        self.bot3 = DoubleConv(256, 128)

        self.up1 = Up(256, 64)
        self.sa3 = SelfAttention(64, 16)
        self.up2 = Up(128, 32)
        self.sa4 = SelfAttention(32, 32)
        self.outc = nn.Conv2d(32, c_out, kernel_size=1)

    def pos_encoding(self, t, channels):
        inv_freq = 1.0 / (
            10000
            ** (torch.arange(0, channels, 2, device=self.device).float() / channels)
        )
        pos_enc_a = torch.sin(t.repeat(1, channels // 2) * inv_freq)
        pos_enc_b = torch.cos(t.repeat(1, channels // 2) * inv_freq)
        pos_enc = torch.cat([pos_enc_a, pos_enc_b], dim=-1)
        return pos_enc

    def forward(self, x, t):
        t = t.unsqueeze(-1).type(torch.float)
        t = self.pos_encoding(t, self.time_dim)

        x1 = self.inc(x)
        x2 = self.down1(x1, t)
        x2 = self.sa1(x2)
        x3 = self.down2(x2, t)
        x3 = self.sa2(x3)

        x3 = self.bot1(x3)
        x3 = self.bot2(x3)
        x3 = self.bot3(x3)

        x = self.up1(x3, x2, t)
        x = self.sa3(x)
        x = self.up2(x, x1, t)
        x = self.sa4(x)
        output = self.outc(x)
        return output

# %%
model = UNet(3, 3).to(device)

# %%
from PIL import Image

def save_images(images, path, **kwargs):
    grid = torchvision.utils.make_grid(images, **kwargs)
    ndarr = grid.permute(1, 2, 0).to('cpu').numpy()
    im = Image.fromarray(ndarr)
    im.save(path)

# %%
import csv

EPOCHS = 800
criterion = nn.MSELoss()
optim = torch.optim.Adam(model.parameters(), lr=2e-4)

loss_file = "./res/loss.csv"
file = open(loss_file, "a", newline="")
writer = csv.writer(file)

loss_list = []

for epoch in range(EPOCHS):
    batch = 1
    for x0s, label in dataloader:
        ts = torch.randint(low=1, high=1000, size=(x0s.shape[0],), device=device)
        xts, added_noise = diffusion_helper.add_noise(x0s.to(device), ts)

        pred_noise = model(xts, ts)

        loss = criterion(added_noise, pred_noise)

        optim.zero_grad()
        loss.backward()
        optim.step()

        # if batch % 50 == 0:
        #   print(f"Epoch {epoch+1}, Batch {batch}/{len(dataloader)}")

        batch += 1

    print(f"Epoch {epoch+1}, Loss: {loss.item():.4f}")
    loss_list.append(round(loss.item(), 5))
    writer.writerow([round(loss.item(), 5)])

    if (epoch+1) % 50 == 0:
      samp_images = diffusion_helper.sample(model, x0s.shape[0])
      save_images(samp_images, os.path.join(res_folder, f"{epoch+1}.jpg"))
      torch.save(model.state_dict(), os.path.join(check_point_dir,f"{epoch+1}_ckpt.pt"))

file.close()
print("Training done")
# Out:
# Epoch 1, Loss: 0.1101
# Epoch 2, Loss: 0.1062
# Epoch 3, Loss: 0.0539
# Epoch 4, Loss: 0.0607
# Epoch 5, Loss: 0.0401
# Epoch 6, Loss: 0.0594
# Epoch 7, Loss: 0.0529
# Epoch 8, Loss: 0.0695
# Epoch 9, Loss: 0.0454
# Epoch 10, Loss: 0.0323
# Epoch 11, Loss: 0.0266
# Epoch 12, Loss: 0.0608
# Epoch 13, Loss: 0.0244
# Epoch 14, Loss: 0.0383
# Epoch 15, Loss: 0.2028
# Epoch 16, Loss: 0.0505
# Epoch 17, Loss: 0.1028
# Epoch 18, Loss: 0.0490
# Epoch 19, Loss: 0.0151
# Epoch 20, Loss: 0.1022
# Epoch 21, Loss: 0.0349
# Epoch 22, Loss: 0.0385
# Epoch 23, Loss: 0.1534
# Epoch 24, Loss: 0.0241
# Epoch 25, Loss: 0.0778
# Epoch 26, Loss: 0.0633
# Epoch 27, Loss: 0.0793
# Epoch 28, Loss: 0.0428
# Epoch 29, Loss: 0.0625
# Epoch 30, Loss: 0.0771
# Epoch 31, Loss: 0.0209
# Epoch 32, Loss: 0.0575
# Epoch 33, Loss: 0.0294
# Epoch 34, Loss: 0.0222
# Epoch 35, Loss: 0.0140
# Epoch 36, Loss: 0.0299
# Epoch 37, Loss: 0.0981
# Epoch 38, Loss: 0.0915
# Epoch 39, Loss: 0.0768
# Epoch 40, Loss: 0.0517
# Epoch 41, Loss: 0.0190
# Epoch 42, Loss: 0.0451
# Epoch 43, Loss: 0.0510
# Epoch 44, Loss: 0.0813
# Epoch 45, Loss: 0.0402
# Epoch 46, Loss: 0.0238
# Epoch 47, Loss: 0.0285
# Epoch 48, Loss: 0.0330
# Epoch 49, Loss: 0.0147
# Epoch 50, Loss: 0.0355
# Epoch 51, Loss: 0.0571
# Epoch 52, Loss: 0.0181
# Epoch 53, Loss: 0.0444
# Epoch 54, Loss: 0.0483
# Epoch 55, Loss: 0.0111
# Epoch 56, Loss: 0.1202
# Epoch 57, Loss: 0.0826
# Epoch 58, Loss: 0.0792
# Epoch 59, Loss: 0.0096
# Epoch 60, Loss: 0.0364
# Epoch 61, Loss: 0.0208
# Epoch 62, Loss: 0.0316
# Epoch 63, Loss: 0.0217
# Epoch 64, Loss: 0.0532
# Epoch 65, Loss: 0.0805
# Epoch 66, Loss: 0.0409
# Epoch 67, Loss: 0.0149
# Epoch 68, Loss: 0.0154
# Epoch 69, Loss: 0.0338
# Epoch 70, Loss: 0.0153
# Epoch 71, Loss: 0.0174
# Epoch 72, Loss: 0.0136
# Epoch 73, Loss: 0.0077
# Epoch 74, Loss: 0.0495
# Epoch 75, Loss: 0.0519
# Epoch 76, Loss: 0.0470
# Epoch 77, Loss: 0.0897
# Epoch 78, Loss: 0.1390
# Epoch 79, Loss: 0.1125
# Epoch 80, Loss: 0.0505
# Epoch 81, Loss: 0.0583
# Epoch 82, Loss: 0.0240
# Epoch 83, Loss: 0.0109
# Epoch 84, Loss: 0.0239
# Epoch 85, Loss: 0.0391
# Epoch 86, Loss: 0.0338
# Epoch 87, Loss: 0.0487
# Epoch 88, Loss: 0.0338
# Epoch 89, Loss: 0.0180
# Epoch 90, Loss: 0.0857
# Epoch 91, Loss: 0.0357
# Epoch 92, Loss: 0.0472
# Epoch 93, Loss: 0.0647
# Epoch 94, Loss: 0.0242
# Epoch 95, Loss: 0.0417
# Epoch 96, Loss: 0.0343
# Epoch 97, Loss: 0.0217
# Epoch 98, Loss: 0.0651
# Epoch 99, Loss: 0.0337
# Epoch 100, Loss: 0.0188
# Epoch 101, Loss: 0.0643
# Epoch 102, Loss: 0.0381
# Epoch 103, Loss: 0.0583
# Epoch 104, Loss: 0.0291
# Epoch 105, Loss: 0.0659
# Epoch 106, Loss: 0.0271
# Epoch 107, Loss: 0.0289
# Epoch 108, Loss: 0.0651
# Epoch 109, Loss: 0.0208
# Epoch 110, Loss: 0.0491
# Epoch 111, Loss: 0.0846
# Epoch 112, Loss: 0.0469
# Epoch 113, Loss: 0.0893
# Epoch 114, Loss: 0.0374
# Epoch 115, Loss: 0.0119
# Epoch 116, Loss: 0.0848
# Epoch 117, Loss: 0.0656
# Epoch 118, Loss: 0.0621
# Epoch 119, Loss: 0.0257
# Epoch 120, Loss: 0.0423
# Epoch 121, Loss: 0.0614
# Epoch 122, Loss: 0.0167
# Epoch 123, Loss: 0.0433
# Epoch 124, Loss: 0.0731
# Epoch 125, Loss: 0.0759
# Epoch 126, Loss: 0.1281
# Epoch 127, Loss: 0.0316
# Epoch 128, Loss: 0.0282
# Epoch 129, Loss: 0.0144
# Epoch 130, Loss: 0.0150
# Epoch 131, Loss: 0.0481
# Epoch 132, Loss: 0.0112
# Epoch 133, Loss: 0.0332
# Epoch 134, Loss: 0.0940
# Epoch 135, Loss: 0.0469
# Epoch 136, Loss: 0.0164
# Epoch 137, Loss: 0.0398
# Epoch 138, Loss: 0.0225
# Epoch 139, Loss: 0.0079
# Epoch 140, Loss: 0.0094
# Epoch 141, Loss: 0.0297
# Epoch 142, Loss: 0.0386
# Epoch 143, Loss: 0.0555
# Epoch 144, Loss: 0.0060
# Epoch 145, Loss: 0.0471
# Epoch 146, Loss: 0.0337
# Epoch 147, Loss: 0.0213
# Epoch 148, Loss: 0.0075
# Epoch 149, Loss: 0.0589
# Epoch 150, Loss: 0.0560
# Epoch 151, Loss: 0.0119
# Epoch 152, Loss: 0.0455
# Epoch 153, Loss: 0.0225
# Epoch 154, Loss: 0.0368
# Epoch 155, Loss: 0.0491
# Epoch 156, Loss: 0.0306
# Epoch 157, Loss: 0.0366
# Epoch 158, Loss: 0.0121
# Epoch 159, Loss: 0.0368
# Epoch 160, Loss: 0.0654
# Epoch 161, Loss: 0.0292
# Epoch 162, Loss: 0.0428
# Epoch 163, Loss: 0.0203
# Epoch 164, Loss: 0.0336
# Epoch 165, Loss: 0.0257
# Epoch 166, Loss: 0.0082
# Epoch 167, Loss: 0.0601
# Epoch 168, Loss: 0.0792
# Epoch 169, Loss: 0.0276
# Epoch 170, Loss: 0.0332
# Epoch 171, Loss: 0.0428
# Epoch 172, Loss: 0.0184
# Epoch 173, Loss: 0.0550
# Epoch 174, Loss: 0.0789
# Epoch 175, Loss: 0.0418
# Epoch 176, Loss: 0.0810
# Epoch 177, Loss: 0.0382
# Epoch 178, Loss: 0.0090
# Epoch 179, Loss: 0.0359
# Epoch 180, Loss: 0.0410
# Epoch 181, Loss: 0.1075
# Epoch 182, Loss: 0.0279
# Epoch 183, Loss: 0.0163
# Epoch 184, Loss: 0.0305
# Epoch 185, Loss: 0.0113
# Epoch 186, Loss: 0.0204
# Epoch 187, Loss: 0.0119
# Epoch 188, Loss: 0.0471
# Epoch 189, Loss: 0.0329
# Epoch 190, Loss: 0.0124
# Epoch 191, Loss: 0.0309
# Epoch 192, Loss: 0.0453
# Epoch 193, Loss: 0.0655
# Epoch 194, Loss: 0.0309
# Epoch 195, Loss: 0.0176
# Epoch 196, Loss: 0.0338
# Epoch 197, Loss: 0.0442
# Epoch 198, Loss: 0.0522
# Epoch 199, Loss: 0.0067
# Epoch 200, Loss: 0.1057
# Epoch 201, Loss: 0.0403
# Epoch 202, Loss: 0.1113
# Epoch 203, Loss: 0.0161
# Epoch 204, Loss: 0.0274
# Epoch 205, Loss: 0.0615
# Epoch 206, Loss: 0.0646
# Epoch 207, Loss: 0.0322
# Epoch 208, Loss: 0.0699
# Epoch 209, Loss: 0.0260
# Epoch 210, Loss: 0.0036
# Epoch 211, Loss: 0.0343
# Epoch 212, Loss: 0.0374
# Epoch 213, Loss: 0.0113
# Epoch 214, Loss: 0.0646
# Epoch 215, Loss: 0.0200
# Epoch 216, Loss: 0.0283
# Epoch 217, Loss: 0.0912
# Epoch 218, Loss: 0.0050
# Epoch 219, Loss: 0.0266
# Epoch 220, Loss: 0.0330
# Epoch 221, Loss: 0.0423
# Epoch 222, Loss: 0.0178
# Epoch 223, Loss: 0.0545
# Epoch 224, Loss: 0.0503
# Epoch 225, Loss: 0.0113
# Epoch 226, Loss: 0.0146
# Epoch 227, Loss: 0.0567
# Epoch 228, Loss: 0.0346
# Epoch 229, Loss: 0.0115
# Epoch 230, Loss: 0.0595
# Epoch 231, Loss: 0.0097
# Epoch 232, Loss: 0.0297
# Epoch 233, Loss: 0.0289
# Epoch 234, Loss: 0.0164
# Epoch 235, Loss: 0.0211
# Epoch 236, Loss: 0.0190
# Epoch 237, Loss: 0.0617
# Epoch 238, Loss: 0.0104
# Epoch 239, Loss: 0.0279
# Epoch 240, Loss: 0.0313
# Epoch 241, Loss: 0.0430
# Epoch 242, Loss: 0.0138
# Epoch 243, Loss: 0.0774
# Epoch 244, Loss: 0.0107
# Epoch 245, Loss: 0.0308
# Epoch 246, Loss: 0.0394
# Epoch 247, Loss: 0.0110
# Epoch 248, Loss: 0.0847
# Epoch 249, Loss: 0.0693
# Epoch 250, Loss: 0.0232
# Epoch 251, Loss: 0.0409
# Epoch 252, Loss: 0.0526
# Epoch 253, Loss: 0.0432
# Epoch 254, Loss: 0.0731
# Epoch 255, Loss: 0.0216
# Epoch 256, Loss: 0.0414
# Epoch 257, Loss: 0.0204
# Epoch 258, Loss: 0.0135
# Epoch 259, Loss: 0.0811
# Epoch 260, Loss: 0.0148
# Epoch 261, Loss: 0.0807
# Epoch 262, Loss: 0.0413
# Epoch 263, Loss: 0.0539
# Epoch 264, Loss: 0.0330
# Epoch 265, Loss: 0.0632
# Epoch 266, Loss: 0.0062
# Epoch 267, Loss: 0.0388
# Epoch 268, Loss: 0.0320
# Epoch 269, Loss: 0.0369
# Epoch 270, Loss: 0.0160
# Epoch 271, Loss: 0.0287
# Epoch 272, Loss: 0.0298
# Epoch 273, Loss: 0.0126
# Epoch 274, Loss: 0.0405
# Epoch 275, Loss: 0.0174
# Epoch 276, Loss: 0.0172
# Epoch 277, Loss: 0.0128
# Epoch 278, Loss: 0.0173
# Epoch 279, Loss: 0.0244
# Epoch 280, Loss: 0.1042
# Epoch 281, Loss: 0.0367
# Epoch 282, Loss: 0.0135
# Epoch 283, Loss: 0.0295
# Epoch 284, Loss: 0.0365
# Epoch 285, Loss: 0.0401
# Epoch 286, Loss: 0.0592
# Epoch 287, Loss: 0.0434
# Epoch 288, Loss: 0.0360
# Epoch 289, Loss: 0.0021
# Epoch 290, Loss: 0.0812
# Epoch 291, Loss: 0.0266
# Epoch 292, Loss: 0.0416
# Epoch 293, Loss: 0.0570
# Epoch 294, Loss: 0.0476
# Epoch 295, Loss: 0.0205
# Epoch 296, Loss: 0.0235
# Epoch 297, Loss: 0.0691
# Epoch 298, Loss: 0.0375
# Epoch 299, Loss: 0.0275
# Epoch 300, Loss: 0.0316
# Epoch 301, Loss: 0.0118
# Epoch 302, Loss: 0.0374
# Epoch 303, Loss: 0.0171
# Epoch 304, Loss: 0.0177
# Epoch 305, Loss: 0.0294
# Epoch 306, Loss: 0.0752
# Epoch 307, Loss: 0.0177
# Epoch 308, Loss: 0.0516
# Epoch 309, Loss: 0.0647
# Epoch 310, Loss: 0.0250
# Epoch 311, Loss: 0.0227
# Epoch 312, Loss: 0.0354
# Epoch 313, Loss: 0.0219
# Epoch 314, Loss: 0.0409
# Epoch 315, Loss: 0.0193
# Epoch 316, Loss: 0.0147
# Epoch 317, Loss: 0.0220
# Epoch 318, Loss: 0.0292
# Epoch 319, Loss: 0.0436
# Epoch 320, Loss: 0.0576
# Epoch 321, Loss: 0.1343
# Epoch 322, Loss: 0.0606
# Epoch 323, Loss: 0.0531
# Epoch 324, Loss: 0.0383
# Epoch 325, Loss: 0.0185
# Epoch 326, Loss: 0.0286
# Epoch 327, Loss: 0.0328
# Epoch 328, Loss: 0.0198
# Epoch 329, Loss: 0.0200
# Epoch 330, Loss: 0.0513
# Epoch 331, Loss: 0.0082
# Epoch 332, Loss: 0.0828
# Epoch 333, Loss: 0.0322
# Epoch 334, Loss: 0.0387
# Epoch 335, Loss: 0.0726
# Epoch 336, Loss: 0.0624
# Epoch 337, Loss: 0.1059
# Epoch 338, Loss: 0.0511
# Epoch 339, Loss: 0.1118
# Epoch 340, Loss: 0.0169
# Epoch 341, Loss: 0.1264
# Epoch 342, Loss: 0.0252
# Epoch 343, Loss: 0.0609
# Epoch 344, Loss: 0.0208
# Epoch 345, Loss: 0.0534
# Epoch 346, Loss: 0.0279
# Epoch 347, Loss: 0.0147
# Epoch 348, Loss: 0.0183
# Epoch 349, Loss: 0.0657
# Epoch 350, Loss: 0.0141
# Epoch 351, Loss: 0.0444
# Epoch 352, Loss: 0.1109
# Epoch 353, Loss: 0.0452
# Epoch 354, Loss: 0.0360
# Epoch 355, Loss: 0.0354
# Epoch 356, Loss: 0.0242
# Epoch 357, Loss: 0.0131
# Epoch 358, Loss: 0.0261
# Epoch 359, Loss: 0.0712
# Epoch 360, Loss: 0.0434
# Epoch 361, Loss: 0.0159
# Epoch 362, Loss: 0.0229
# Epoch 363, Loss: 0.0242
# Epoch 364, Loss: 0.0138
# Epoch 365, Loss: 0.0262
# Epoch 366, Loss: 0.0719
# Epoch 367, Loss: 0.0147
# Epoch 368, Loss: 0.0307
# Epoch 369, Loss: 0.1055
# Epoch 370, Loss: 0.0217
# Epoch 371, Loss: 0.0130
# Epoch 372, Loss: 0.0879
# Epoch 373, Loss: 0.0289
# Epoch 374, Loss: 0.0319
# Epoch 375, Loss: 0.0219
# Epoch 376, Loss: 0.0193
# Epoch 377, Loss: 0.0638
# Epoch 378, Loss: 0.0636
# Epoch 379, Loss: 0.0334
# Epoch 380, Loss: 0.0314
# Epoch 381, Loss: 0.0176
# Epoch 382, Loss: 0.0516
# Epoch 383, Loss: 0.0319
# Epoch 384, Loss: 0.0336
# Epoch 385, Loss: 0.0358
# Epoch 386, Loss: 0.0172
# Epoch 387, Loss: 0.0415
# Epoch 388, Loss: 0.0401
# Epoch 389, Loss: 0.0464
# Epoch 390, Loss: 0.0198
# Epoch 391, Loss: 0.0297
# Epoch 392, Loss: 0.0529
# Epoch 393, Loss: 0.0179
# Epoch 394, Loss: 0.0615
# Epoch 395, Loss: 0.0158
# Epoch 396, Loss: 0.0162
# Epoch 397, Loss: 0.0622
# Epoch 398, Loss: 0.0552
# Epoch 399, Loss: 0.0184
# Epoch 400, Loss: 0.0674
# Epoch 401, Loss: 0.0198
# Epoch 402, Loss: 0.0264
# Epoch 403, Loss: 0.0595
# Epoch 404, Loss: 0.0534
# Epoch 405, Loss: 0.0059
# Epoch 406, Loss: 0.0444
# Epoch 407, Loss: 0.0526
# Epoch 408, Loss: 0.0762
# Epoch 409, Loss: 0.0351
# Epoch 410, Loss: 0.1021
# Epoch 411, Loss: 0.0123
# Epoch 412, Loss: 0.0154
# Epoch 413, Loss: 0.0285
# Epoch 414, Loss: 0.0363
# Epoch 415, Loss: 0.0088
# Epoch 416, Loss: 0.1285
# Epoch 417, Loss: 0.0331
# Epoch 418, Loss: 0.0318
# Epoch 419, Loss: 0.0503
# Epoch 420, Loss: 0.0277
# Epoch 421, Loss: 0.1015
# Epoch 422, Loss: 0.0748
# Epoch 423, Loss: 0.0393
# Epoch 424, Loss: 0.0371
# Epoch 425, Loss: 0.0236
# Epoch 426, Loss: 0.0438
# Epoch 427, Loss: 0.0090
# Epoch 428, Loss: 0.0111
# Epoch 429, Loss: 0.0341
# Epoch 430, Loss: 0.0179
# Epoch 431, Loss: 0.0404
# Epoch 432, Loss: 0.0361
# Epoch 433, Loss: 0.0300
# Epoch 434, Loss: 0.0913
# Epoch 435, Loss: 0.0273
# Epoch 436, Loss: 0.0043
# Epoch 437, Loss: 0.0265
# Epoch 438, Loss: 0.0713
# Epoch 439, Loss: 0.0534
# Epoch 440, Loss: 0.0328
# Epoch 441, Loss: 0.0305
# Epoch 442, Loss: 0.0366
# Epoch 443, Loss: 0.0618
# Epoch 444, Loss: 0.0466
# Epoch 445, Loss: 0.0781
# Epoch 446, Loss: 0.0776
# Epoch 447, Loss: 0.0978
# Epoch 448, Loss: 0.0146
# Epoch 449, Loss: 0.0170
# Epoch 450, Loss: 0.0368
# Epoch 451, Loss: 0.0545
# Epoch 452, Loss: 0.0620
# Epoch 453, Loss: 0.0301
# Epoch 454, Loss: 0.0189
# Epoch 455, Loss: 0.0139
# Epoch 456, Loss: 0.0187
# Epoch 457, Loss: 0.0236
# Epoch 458, Loss: 0.0192
# Epoch 459, Loss: 0.0116
# Epoch 460, Loss: 0.0307
# Epoch 461, Loss: 0.0314
# Epoch 462, Loss: 0.0345
# Epoch 463, Loss: 0.0146
# Epoch 464, Loss: 0.0072
# Epoch 465, Loss: 0.0275
# Epoch 466, Loss: 0.0799
# Epoch 467, Loss: 0.0453
# Epoch 468, Loss: 0.0209
# Epoch 469, Loss: 0.0077
# Epoch 470, Loss: 0.0259
# Epoch 471, Loss: 0.0617
# Epoch 472, Loss: 0.0238
# Epoch 473, Loss: 0.0098
# Epoch 474, Loss: 0.0351
# Epoch 475, Loss: 0.0188
# Epoch 476, Loss: 0.0156
# Epoch 477, Loss: 0.0593
# Epoch 478, Loss: 0.0284
# Epoch 479, Loss: 0.0733
# Epoch 480, Loss: 0.0966
# Epoch 481, Loss: 0.0659
# Epoch 482, Loss: 0.0529
# Epoch 483, Loss: 0.0350
# Epoch 484, Loss: 0.0507
# Epoch 485, Loss: 0.0277
# Epoch 486, Loss: 0.0236
# Epoch 487, Loss: 0.0129
# Epoch 488, Loss: 0.0320
# Epoch 489, Loss: 0.0246
# Epoch 490, Loss: 0.0170
# Epoch 491, Loss: 0.0725
# Epoch 492, Loss: 0.0462
# Epoch 493, Loss: 0.0189
# Epoch 494, Loss: 0.0479
# Epoch 495, Loss: 0.0197
# Epoch 496, Loss: 0.0298
# Epoch 497, Loss: 0.0270
# Epoch 498, Loss: 0.0224
# Epoch 499, Loss: 0.0882
# Epoch 500, Loss: 0.0369
# Epoch 501, Loss: 0.0409
# Epoch 502, Loss: 0.0474
# Epoch 503, Loss: 0.0449
# Epoch 504, Loss: 0.0504
# Epoch 505, Loss: 0.0219
# Epoch 506, Loss: 0.0219
# Epoch 507, Loss: 0.0251
# Epoch 508, Loss: 0.0167
# Epoch 509, Loss: 0.0217
# Epoch 510, Loss: 0.0188
# Epoch 511, Loss: 0.0227
# Epoch 512, Loss: 0.0332
# Epoch 513, Loss: 0.0296
# Epoch 514, Loss: 0.0057
# Epoch 515, Loss: 0.0475
# Epoch 516, Loss: 0.0380
# Epoch 517, Loss: 0.0407
# Epoch 518, Loss: 0.0506
# Epoch 519, Loss: 0.0098
# Epoch 520, Loss: 0.0173
# Epoch 521, Loss: 0.0620
# Epoch 522, Loss: 0.0149
# Epoch 523, Loss: 0.0391
# Epoch 524, Loss: 0.0363
# Epoch 525, Loss: 0.0588
# Epoch 526, Loss: 0.0113
# Epoch 527, Loss: 0.0192
# Epoch 528, Loss: 0.0047
# Epoch 529, Loss: 0.0876
# Epoch 530, Loss: 0.0161
# Epoch 531, Loss: 0.0628
# Epoch 532, Loss: 0.1020
# Epoch 533, Loss: 0.0933
# Epoch 534, Loss: 0.0174
# Epoch 535, Loss: 0.0040
# Epoch 536, Loss: 0.0383
# Epoch 537, Loss: 0.0396
# Epoch 538, Loss: 0.0353
# Epoch 539, Loss: 0.0170
# Epoch 540, Loss: 0.0076
# Epoch 541, Loss: 0.0510
# Epoch 542, Loss: 0.0223
# Epoch 543, Loss: 0.0049
# Epoch 544, Loss: 0.0198
# Epoch 545, Loss: 0.0537
# Epoch 546, Loss: 0.1495
# Epoch 547, Loss: 0.0237
# Epoch 548, Loss: 0.0196
# Epoch 549, Loss: 0.0174
# Epoch 550, Loss: 0.0150
# Epoch 551, Loss: 0.0103
# Epoch 552, Loss: 0.0192
# Epoch 553, Loss: 0.0204
# Epoch 554, Loss: 0.0200
# Epoch 555, Loss: 0.0333
# Epoch 556, Loss: 0.0236
# Epoch 557, Loss: 0.0316
# Epoch 558, Loss: 0.0570
# Epoch 559, Loss: 0.0233
# Epoch 560, Loss: 0.0291
# Epoch 561, Loss: 0.0909
# Epoch 562, Loss: 0.0050
# Epoch 563, Loss: 0.0829
# Epoch 564, Loss: 0.0360
# Epoch 565, Loss: 0.0750
# Epoch 566, Loss: 0.0036
# Epoch 567, Loss: 0.0136
# Epoch 568, Loss: 0.0518
# Epoch 569, Loss: 0.0635
# Epoch 570, Loss: 0.0395
# Epoch 571, Loss: 0.0099
# Epoch 572, Loss: 0.0252
# Epoch 573, Loss: 0.0310
# Epoch 574, Loss: 0.0571
# Epoch 575, Loss: 0.0200
# Epoch 576, Loss: 0.1106
# Epoch 577, Loss: 0.0537
# Epoch 578, Loss: 0.0168
# Epoch 579, Loss: 0.0359
# Epoch 580, Loss: 0.0138
# Epoch 581, Loss: 0.0235
# Epoch 582, Loss: 0.0702
# Epoch 583, Loss: 0.0226
# Epoch 584, Loss: 0.0089
# Epoch 585, Loss: 0.0464
# Epoch 586, Loss: 0.0561
# Epoch 587, Loss: 0.0137
# Epoch 588, Loss: 0.0325
# Epoch 589, Loss: 0.0374
# Epoch 590, Loss: 0.0227
# Epoch 591, Loss: 0.0341
# Epoch 592, Loss: 0.0903
# Epoch 593, Loss: 0.0596
# Epoch 594, Loss: 0.0235
# Epoch 595, Loss: 0.0377
# Epoch 596, Loss: 0.0170
# Epoch 597, Loss: 0.0476
# Epoch 598, Loss: 0.0727
# Epoch 599, Loss: 0.0435
# Epoch 600, Loss: 0.1001
# Epoch 601, Loss: 0.0727
# Epoch 602, Loss: 0.0227
# Epoch 603, Loss: 0.0832
# Epoch 604, Loss: 0.0361
# Epoch 605, Loss: 0.0550
# Epoch 606, Loss: 0.0399
# Epoch 607, Loss: 0.0151
# Epoch 608, Loss: 0.0496
# Epoch 609, Loss: 0.0280
# Epoch 610, Loss: 0.0321
# Epoch 611, Loss: 0.0483
# Epoch 612, Loss: 0.0778
# Epoch 613, Loss: 0.0295
# Epoch 614, Loss: 0.0341
# Epoch 615, Loss: 0.0089
# Epoch 616, Loss: 0.0563
# Epoch 617, Loss: 0.0231
# Epoch 618, Loss: 0.0204
# Epoch 619, Loss: 0.0542
# Epoch 620, Loss: 0.0401
# Epoch 621, Loss: 0.0321
# Epoch 622, Loss: 0.0613
# Epoch 623, Loss: 0.0164
# Epoch 624, Loss: 0.0319
# Epoch 625, Loss: 0.0633
# Epoch 626, Loss: 0.0510
# Epoch 627, Loss: 0.0853
# Epoch 628, Loss: 0.0219
# Epoch 629, Loss: 0.0235
# Epoch 630, Loss: 0.0753
# Epoch 631, Loss: 0.0420
# Epoch 632, Loss: 0.0793
# Epoch 633, Loss: 0.0262
# Epoch 634, Loss: 0.0268
# Epoch 635, Loss: 0.0090
# Epoch 636, Loss: 0.0195
# Epoch 637, Loss: 0.0129
# Epoch 638, Loss: 0.0134
# Epoch 639, Loss: 0.0314
# Epoch 640, Loss: 0.0126
# Epoch 641, Loss: 0.0373
# Epoch 642, Loss: 0.0832
# Epoch 643, Loss: 0.0522
# Epoch 644, Loss: 0.0960
# Epoch 645, Loss: 0.0361
# Epoch 646, Loss: 0.0168
# Epoch 647, Loss: 0.0795
# Epoch 648, Loss: 0.0671
# Epoch 649, Loss: 0.0132
# Epoch 650, Loss: 0.0182
# Epoch 651, Loss: 0.0365
# Epoch 652, Loss: 0.0534
# Epoch 653, Loss: 0.0147
# Epoch 654, Loss: 0.0396
# Epoch 655, Loss: 0.0485
# Epoch 656, Loss: 0.0219
# Epoch 657, Loss: 0.0198
# Epoch 658, Loss: 0.0182
# Epoch 659, Loss: 0.0645
# Epoch 660, Loss: 0.0159
# Epoch 661, Loss: 0.0478
# Epoch 662, Loss: 0.0399
# Epoch 663, Loss: 0.0716
# Epoch 664, Loss: 0.0110
# Epoch 665, Loss: 0.0169
# Epoch 666, Loss: 0.0183
# Epoch 667, Loss: 0.0329
# Epoch 668, Loss: 0.0339
# Epoch 669, Loss: 0.0810
# Epoch 670, Loss: 0.0141
# Epoch 671, Loss: 0.0172
# Epoch 672, Loss: 0.0396
# Epoch 673, Loss: 0.0355
# Epoch 674, Loss: 0.0627
# Epoch 675, Loss: 0.0496
# Epoch 676, Loss: 0.0135
# Epoch 677, Loss: 0.0114
# Epoch 678, Loss: 0.0133
# Epoch 679, Loss: 0.0102
# Epoch 680, Loss: 0.0476
# Epoch 681, Loss: 0.0164
# Epoch 682, Loss: 0.0129
# Epoch 683, Loss: 0.0547
# Epoch 684, Loss: 0.0211
# Epoch 685, Loss: 0.0103
# Epoch 686, Loss: 0.0364
# Epoch 687, Loss: 0.0217
# Epoch 688, Loss: 0.0355
# Epoch 689, Loss: 0.0555
# Epoch 690, Loss: 0.0098
# Epoch 691, Loss: 0.0274
# Epoch 692, Loss: 0.0613
# Epoch 693, Loss: 0.0426
# Epoch 694, Loss: 0.0214
# Epoch 695, Loss: 0.0248
# Epoch 696, Loss: 0.0174
# Epoch 697, Loss: 0.0072
# Epoch 698, Loss: 0.0123
# Epoch 699, Loss: 0.0087
# Epoch 700, Loss: 0.0068
# Epoch 701, Loss: 0.0498
# Epoch 702, Loss: 0.0512
# Epoch 703, Loss: 0.0205
# Epoch 704, Loss: 0.0645
# Epoch 705, Loss: 0.0094
# Epoch 706, Loss: 0.0629
# Epoch 707, Loss: 0.0290
# Epoch 708, Loss: 0.0128
# Epoch 709, Loss: 0.0372
# Epoch 710, Loss: 0.0691
# Epoch 711, Loss: 0.0113
# Epoch 712, Loss: 0.0549
# Epoch 713, Loss: 0.0221
# Epoch 714, Loss: 0.0459
# Epoch 715, Loss: 0.0581
# Epoch 716, Loss: 0.0578
# Epoch 717, Loss: 0.0163
# Epoch 718, Loss: 0.0429
# Epoch 719, Loss: 0.0562
# Epoch 720, Loss: 0.1112
# Epoch 721, Loss: 0.0379
# Epoch 722, Loss: 0.0595
# Epoch 723, Loss: 0.0311
# Epoch 724, Loss: 0.0206
# Epoch 725, Loss: 0.0126
# Epoch 726, Loss: 0.0510
# Epoch 727, Loss: 0.0104
# Epoch 728, Loss: 0.0647
# Epoch 729, Loss: 0.0449
# Epoch 730, Loss: 0.0134
# Epoch 731, Loss: 0.0411
# Epoch 732, Loss: 0.0253
# Epoch 733, Loss: 0.0814
# Epoch 734, Loss: 0.0261
# Epoch 735, Loss: 0.0124
# Epoch 736, Loss: 0.0481
# Epoch 737, Loss: 0.0073
# Epoch 738, Loss: 0.0081
# Epoch 739, Loss: 0.0360
# Epoch 740, Loss: 0.0143
# Epoch 741, Loss: 0.0178
# Epoch 742, Loss: 0.0739
# Epoch 743, Loss: 0.0465
# Epoch 744, Loss: 0.0086
# Epoch 745, Loss: 0.0473
# Epoch 746, Loss: 0.0672
# Epoch 747, Loss: 0.0234
# Epoch 748, Loss: 0.0534
# Epoch 749, Loss: 0.0280
# Epoch 750, Loss: 0.0579
# Epoch 751, Loss: 0.0165
# Epoch 752, Loss: 0.0593
# Epoch 753, Loss: 0.0145
# Epoch 754, Loss: 0.0203
# Epoch 755, Loss: 0.0239
# Epoch 756, Loss: 0.0445
# Epoch 757, Loss: 0.0096
# Epoch 758, Loss: 0.0190
# Epoch 759, Loss: 0.0553
# Epoch 760, Loss: 0.0083
# Epoch 761, Loss: 0.0348
# Epoch 762, Loss: 0.0436
# Epoch 763, Loss: 0.0075
# Epoch 764, Loss: 0.0801
# Epoch 765, Loss: 0.0629
# Epoch 766, Loss: 0.1254
# Epoch 767, Loss: 0.0301
# Epoch 768, Loss: 0.0198
# Epoch 769, Loss: 0.0140
# Epoch 770, Loss: 0.0489
# Epoch 771, Loss: 0.0418
# Epoch 772, Loss: 0.0190
# Epoch 773, Loss: 0.0595
# Epoch 774, Loss: 0.0147
# Epoch 775, Loss: 0.0528
# Epoch 776, Loss: 0.0098
# Epoch 777, Loss: 0.0114
# Epoch 778, Loss: 0.0406
# Epoch 779, Loss: 0.0215
# Epoch 780, Loss: 0.0284
# Epoch 781, Loss: 0.0407
# Epoch 782, Loss: 0.0115
# Epoch 783, Loss: 0.0266
# Epoch 784, Loss: 0.0899
# Epoch 785, Loss: 0.0631
# Epoch 786, Loss: 0.0145
# Epoch 787, Loss: 0.0135
# Epoch 788, Loss: 0.0396
# Epoch 789, Loss: 0.0613
# Epoch 790, Loss: 0.0301
# Epoch 791, Loss: 0.0372
# Epoch 792, Loss: 0.0190
# Epoch 793, Loss: 0.0067
# Epoch 794, Loss: 0.0866
# Epoch 795, Loss: 0.0264
# Epoch 796, Loss: 0.0154
# Epoch 797, Loss: 0.0112
# Epoch 798, Loss: 0.0333
# Epoch 799, Loss: 0.0214
# Epoch 800, Loss: 0.0673
# Training done
